# %% [markdown]
# <a href="https://colab.research.google.com/github/luannfa/INTED2025M/blob/main/ALP_M33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorítmo e Lógica de Programação

# %% [markdown]
# ##Variáveis

# %%
a = 50
b = 15
print(a+b)
# Out:
# 65

# %% [markdown]
# ## Tipos de dados
#
# int - inteiros - para números inteiro
#
# float - flutuantes - para números com vírgula
#
# str  - string - para palavras e textos
#
# bool - booleano - para binários - True ou False

# %%
x = int(input("Digite um número: "))
y = float(input("Digite um número com vírgula: "))
z = str(input("Digite uma palavra: "))
w = bool(input("Digite um Binário: "))
# Out:
# Digite um número: 16
# Digite um número com vírgula: 1.5
# Digite uma palavra: palavra
# Digite um Binário: True

# %%
print(x)
print(y)
print(z)
print(w)
# Out:
# 16
# 1.5
# palavra
# True

# %%
print("Este é um número inteiro: ", x, "outro texto")
# Out:
# Este é um número inteiro:  16 outro texto

# %% [markdown]
# 1 -  crie um algoritmo que receba em uma variavel um nome, e em outra uma idade. (nome, idade) depois mostre na tela a seguinte frase:
#
# Eu sou **nome** e tenho **idade** anos!

# %%
nome = str(input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))
print("Eu sou", nome, "e tenho", idade, "anos!")
# Out:
# Digite seu nome: Luann
# Digite sua idade: 36
# Eu sou Luann e tenho 36 anos!

# %% [markdown]
# ##Operadores
#
# Adição +
#
# Subtração -
#
# Multiplicação *
#
# Divisão /
#
# Resto da divisão %
#
# Exponenciação **

# %% [markdown]
# 2 - Crie um algoritmo que leia 2 números e imprima na tela o resultado das operações acima.

# %%
#Entradas
numero1 = int(input("Digite o primeiro número: "))
numero2 = int(input("Digite o segundo número: "))

#Processamento
soma = numero1 + numero2
subt = numero1 - numero2
div = numero1 / numero2
mult = numero1 * numero2
resto = numero1 % numero2
expo = numero1 ** numero2

#Saída
print(f"A soma é: {soma}")
print(f"A subtração é: {subt}")
print(f"A divisão é: {div:.2f}")
print(f"A multiplicação é: {mult}")
print(f"O resto da divisão é: {resto}")
print(f"A exponenciação é: {expo:.2e}")
# Out:
# Digite o primeiro número: 15
# Digite o segundo número: 65
# A soma é: 80
# A subtração é: -50
# A divisão é: 0.23
# A multiplicação é: 975
# O resto da divisão é: 15
# A exponenciação é: 2.79e+76

# %% [markdown]
# 3 - Crie um algoritmo, que receba o nome do usuário, e 3 notas, depois calcule a média na variável (media), e imprima na tela a seguinte frase:
#
# O aluno (nome) está com (media) de média!
